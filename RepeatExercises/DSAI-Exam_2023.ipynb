# %% [markdown]
# # Examen Data Science & AI
#
# - Student: **Student**
# - Studentennummer: **Nummer**
# - Datum: **Datum**
# - Klasgroep: **Klas**

# %% [markdown]
# ## Instructies
#
# Bij een multiple-true-false vraag, geef je antwoorden als volgt (fictief voorbeeld):
#
# 1. Waar
# 2. Niet waar
# 3. Niet waar
# 4. Waar
#
# Ook bij vragen met verschillende deelvragen gebruik je een genummerde lijst (hieronder een fictief voorbeeld). Merk op dat je LaTeX-notatie mag gebruiken voor wiskundige uitrdukkingen.
#
# 1. Een tweezijdige z-toets
# 2. $\overline{x} = 123.456$ (let op! getallen afronden tot 3 cijfers!)
# 3. $g = 112.432$
# 4. $p = 0.567$
# 5. We kunnen de nulhypothese ... (enz.). Er is dus ... (enz.)
#
# **VUL ZELF Markdown- en codeblokken toe voor de volgende vragen! Zorg dat elke vraag beantwoord is! Verwijder ook deze Markdown-cel voordat je indient.**
#
# **Verwijder vóór indienen a.u.b. alle niet gebruikte codeblokken, tekst tussen haakjes (Antwoord op vraag X) en deze instructies. Enkel jouw ingevulde antwoorden blijven over.**

# %%
# Package imports for data science
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic
# Out:
# C:\Users\nealj\AppData\Local\Temp\ipykernel_21852\2678068429.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Vraag 1 [2 pt]
#
# Wat is het meetniveau van elk van deze variabelen? (Nomimaal / Ordinaal / Interval / Ratio)
#
# (1) Het aantal chips in een bus Pringles chips
#
# (2) De smaak van een bus Pringles: original / paprika / hot & spicy / sour cream & onion / ...
#
# (3) De prijs die je betaalde voor de bus Pringles chips
#
# (4) De score die je geeft aan de Pringles chips: zeer slecht / slecht / matig / goed / zeer goed

# %% [markdown]
# ## Antwoorden Vraag 1
#
# (1.1) ratio
#
# (1.2) nominal
#
# (1.3) ratio
#
# (1.4) orindal

# %% [markdown]
# ## Vraag 2 [2 pt]
#
# Vermeld bij hetgeen hierna omschreven, onderzocht en, of getest wordt, telkens waarover het gaat,
# met name:
# * een aselecte steekproef,
# * een selecte steekproef,
# * de populatie of
# * nog iets anders (onbepaald)
#
# 1. De kwaliteitsdienst van een drankenproducent wenst na te gaan of hun flessen van 1 liter water werkelijk 1 liter drankvloeistof bevatten. Men weet dat de inhoud van een fles water
# een normale verdeling volgt: 16 keer 1 fles willekeurig in de tijd tijdens de productie worden
# genomen. Het gemiddelde waterniveau in deze flessen bedraagt 0.94 liter met een steekproefstandaardafwijking
# van 0.06 liter.
# 2. Een muziekanalyst onderzoekt wat de hoogste muzieknoot en de laagste muzieknoot zijn over álle liedjes die vanaf eerste keer (24 mei 1956) tot op vandaag aan de liedjeswedstrijd Eurovisiesongfestival hebben deelgenomen. Daarvoor beluistert en bestudeert hij alleen álle liedjes van de laatste
# editie, dit wil zeggen het Eurosongfestival van 2022.
# 3. Een student heeft een online gesprek met een professor in de sterrekunde. Uitsluitend op basis van dat gesprek besluit de student dat de planeet Mercurius voornamelijk uit gesteente en ijzer bestaat.
# 4. Een industriële onderneming heeft vijfhonderzevenentachtig werknemers. Er gaat 'een gerucht' dat werknemers van het bedrijf onzorgvuldig zijn en het coronavirus verspreiden. De bedrijfsleider neemt geen risico en stelt aan al zijn werknemers voor om zich te laten testen. Iedereen
# zonder uitzondering inclusief de bedrijfsleider zelf doen het, en laten zich dus testen op het al dan niet besmet zijn met het coronavirus.

# %% [markdown]
# ## Antwoorden Vraag 2
#
# (2.1)aselecte steekproef
#
# (2.2)selecte steekproef
#
# (2.3)  nog iets anders(onbepaald)               kdenk misschien ook steekproef?
#
# (2.4) populatie

# %% [markdown]
# ## Vraag 3 [4 pt]
#
# In een mandje liggen zeven vruchten, 4 appelsienen en 3 citroenen. Je neemt ...
# 1. ...juist één vrucht. Wat is de kans dat dit een appelsien is?
# 2. ... één vrucht en vervolgens nog één zonder de eerste terug te leggen. Wat is de kans dat de twee genomen vruchten allebei appelsienen zijn?
# 3. ...twee vruchten, één na één en zonder terugleggen. Wat is de kans dat de tweede vrucht een appelsien is?
# 4. ... een eerste vrucht, zonder te kijken!
# Vervolgens neem je er nog één uit de mand zonder de eerste terug te leggen. Deze tweede vrucht is een appelsien. Wat is nu de kans dat de eerste vrucht een appelsien is?

# %% [markdown]
# ## Antwoorden Vraag 3
#
# (3.1)  4/7
#
#
# (3.2) (4/7) + (3/6)
#
#
# (3.3) (4/7 +3/6) + (3/7 + 4/6)
#
#
# (3.4)(4/7 +3/6) + (3/7 + 4/6) + (4/7) + (3/6)

# %% [markdown]
# ## Vraag 4 [2 pt]
#
# Zij $X$ een toevalsvariabele met gemiddelde $\mu = 20$ en standaardafwijking $\sigma = 4$ en $X$ heeft een onbekende kansverdeling.
# Men neemt een aselecte steekproef van 64 monsters uit de populatie van $X$.
#
# (4.1) Welke kansverdeling volgt $\bar x$ ?
# (A) Normaal met $\mu$ = 20 en $\sigma$ = 4
# (B) Normaal met $\mu$ = 20 en $\sigma$ = 1/2
# (C) Willekeurig met $\mu$ = 20 en $\sigma$ = 4
# (D) Noch A, B of C
#
# (4.2) De $z$-score horende bij $\bar x$ = 19 is
# (A) -2
# (B) -1
# (C) 0
# (D) Noch A, B of C

# %% [markdown]
# ## Antwoorden Vraag 4
#
# (4.1)
#
#
# (4.2)

# %%
m = 20
s = 4
n = 64
sigma = s / np.sqrt(n)
print(sigma)
# Out:
# 0.5

# %%
# 4.1
# (A) niet waar
# (b) niet waar
# (c) niet waar
# (d)  waar

# %%
z = (19 - m) / sigma
print(z)
# Out:
# -2.0

# %%
# 4.2
# (A)  waar
# (b)  niet waar
# (c) niet waar
# (d) niet waar

# %% [markdown]
# ## Vraag 5 [2 pt]
#
# De onderstaande figuur stelt de situatie voor waar onderzoekers een tweezijdige z-test met significantieniveau 10% uitgevoerd hebben op basis van de waarde $\mu_0$ = 173 en $\sigma$ = 7.2. Ze vinden als kritieke grenswaarden $g_{onder}$ = 161.15 en $g_{boven}$ = 184.84.
#
# ![image.png](data:image/png;base64,...)
#
# (1) Wat is kans op een fout van type I?
# (A) Het rode gebied
# (B) Het roze gebied
# (C) Het blauwe gebied
# (D) Het rode gebied + het roze gebied
# (E) Het rode gebied + het blauwe gebied
# (F) Het roze gebied + het blauwe gebied
# (G) Het rode gebied + het roze gebied + het blauwe gebied
#
# (2) Wat is kans op een fout van type II als in werkelijkheid het populatiegemiddelde $\mu_r$ echter 195 is?
# (A) Het rode gebied
# (B) Het roze gebied
# (C) Het blauwe gebied
# (D) Het rode gebied + het roze gebied
# (E) Het rode gebied + het blauwe gebied
# (F) Het roze gebied + het blauwe gebied
# (G) Het rode gebied + het roze gebied + het blauwe gebied

# %% [markdown]
# ## Antwoorden Vraag 5
#
# (5.1) C = alpha = significance level = 10%
#
# (5.2)  A

# %% [markdown]
# ## Vraag 6 [7 pt]
#
# Het bestand bestellingen.csv bevat gegevens van 400 bestellingen
# geplaatst bij een elektronica bedrijf gedurende een periode van meerdere
# maanden. Voor elke bestelling vermeldt het bestand de tijd van de dag,
# het type creditcard dat wordt gebruikt, de regio van het land
# waar de klant woont,....
# We willen weten of er een verband bestaat tussen Time en Region
#
# (1) Welke toets (met significantieniveau 5%) moet je gebruiken om deze onderzoeksvraag te beantwoorden? Wees zo specifiek mogelijk!
# (2) Formuleer de nulhypothese en de alternatieve hypothese
# (3) Maak een plot op basis waarvan je kan inschatten of nulhypothese zal verworpen worden (Geef bij de Antwoorden het commando voor deze plot)
# (4) Bereken de p-waarde
# (5) Trek een besluit op basis van de vorige stap en beantwoord de onderzoeksvraag.
#
# Geef ook een antwoord op de volgende 2 vragen
#
# (6) Bereken het totaal aantal bestelde Items door vrouwen (Female) op een dinsdag (Tue)
# (7) Geef de interkwartielafstand voor Total Cost

# %%
df = pd.read_csv("../dsai-ReeksA/bestellingen.csv", sep=";")
df.head()
# Out:
#    Day       Time     Region Card Type  Gender Buy Category  Items Ordered  \
# 0  Tue    Morning       West  ElecMart  Female         High              4
# 1  Tue    Morning       West     Other  Female       Medium              1
# 2  Tue  Afternoon       West  ElecMart  Female       Medium              5
# 3  Tue  Afternoon  NorthEast     Other  Female          Low              1
# 4  Tue  Afternoon       West  ElecMart    Male       Medium              4
#
#    Total Cost  High Item
# 0      136.97      79.97
# 1       25.55      25.55
# 2      113.95      90.47
# 3        6.82       6.82
# 4      147.32      83.21

# %% [markdown]
# 6.1: Je gebruikt de Chi-sqaured test om te zien of er een verband tussen deze twee kwalitatieve variabelen.
# ### Test procedure
# 6.2
# Formally, the procedure of the $\chi^2$ test for independence runs as follows:
#
# 1. Hypthesis:
#
#    - $H_0$: There is no association between the variables (the differences between observed and expected values are small)
#    - $H_1$: There is an association between the variables (the differences are large)
#
# Conclusion:
#    1. $\chi^2 < g$: do not reject $H_0$; $\chi^2 > g$: reject $H_0$
#    2. $p > \alpha$: do not reject $H_0$; $p < \alpha$: reject $H_0$

# %%
# 6.3
observed = pd.crosstab(df.Time, df.Region)
observed.plot(kind="barh", stacked=True)
# Out:
# <Axes: ylabel='Time'>

# %% [markdown]
# 6.3
#
# Op basis van deze plot hierboven lijkt het niet of er een verband is tussen de variabelen, dit kan je afleiden aan het feit dat in de morning, evening en afternoon de proporties van de regio's relatief hetzelfde blijven

# %%
# 6.4
chi2, p, dof, expected = stats.chi2_contingency(observed)

print("Chi-squared       : %.4f" % chi2)
print("Degrees of freedom: %d" % dof)
print("P-value           : %.4f" % p)
# Out:
# Chi-squared       : 3.5037
# Degrees of freedom: 6
# P-value           : 0.7435

# %% [markdown]
#  # 6.5
#  p: 0.7435 > a : 0.05 => Op basis van de p-waarde zie je dat je de null hypothesis, dus dat er geen verschil is niet gaat rejecten of weigeren, er is dus geen verband tussen de variabelen.

# %%
alpha = 0.05
dimensions = observed.shape
dof = (dimensions[0] - 1) * (dimensions[1] - 1)
g = stats.chi2.isf(alpha, df=dof)
print("Critical value     : %.4f" % g)
# Out:
# Critical value     : 12.5916

# %% [markdown]
# ## 6.5
#
# chi2: 3.5036 < g: 12.5916 => Op basis van de chi-kwadraat en de critical value dus de g zie je ook dat je de H0 niet gaat rejecten of weigeren, er is dus geen verband tussen de variabelen

# %%
# 6.6
gender = df[((df["Gender"] == "Female") & (df["Day"] == "Tue"))]["Items Ordered"].sum()
print(gender)
# Out:
# 128

# %%
# 6.7
percentiles = [0.0, 0.25, 0.5, 0.75, 1.0]

print("Percentiles", percentiles, "\n", df["Total Cost"].quantile(percentiles))
print(
    "Inter Quartile Range:",
    df["Total Cost"].quantile(0.75) - df["Total Cost"].quantile(0.25),
)
print(
    "De interkwartielafstand van totale kost is: ",
    df["Total Cost"].quantile(0.75) - df["Total Cost"].quantile(0.25),
)
# Out:
# Percentiles [0.0, 0.25, 0.5, 0.75, 1.0]
#  0.00      6.8200
# 0.25     83.3225
# 0.50    126.7200
# 0.75    205.2450
# 1.00    485.0100
# Name: Total Cost, dtype: float64
# Inter Quartile Range: 121.92250000000001
# De interkwartielafstand van totale kost is:  121.92250000000001

# %% [markdown]
# ## Antwoorden Vraag 6
#
# (6.1)
#
# (6.2)
#
# (6.3)
#
# (6.4)
#
# (6.5)
#
# (6.6)
#
# (6.7)

# %% [markdown]
# ## Vraag 7 [4 pt]
#
# In de onderstaande figuur vind je een grafiek van een tijdserie (in het blauw) waarbij de Sales per Quarter worden uitgezet. Er worden ook twee vormen van voortschrijdend gemiddelde in kleur getoond.
#
# ![image.png](data:image/png;base64,...)
#
#
#
# (7.1)  Wat is de beste manier om deze tijdserie te modelleren? Kies uit de mogelijkheden hieronder:
# (A) Model van Holt met additieve trend.
# (B) Model van Holt met multiplicatieve trend.
# (C) Model van Holt-Winters met additief seizoenseffect.
# (D) Model van Holt-Winters met multiplicatief seizoenseffect.
#
# (7.2) Wat is de lijn A precies? Kies uit de mogelijkheden hieronder:
# (A) Eenvoudig voortschrijdend gemiddelde met periode 3
# (B) Eenvoudig voortschrijdend gemiddelde met periode 10
# (C) Enkelvoudige exponentiële afvlakking met α = 0.1
# (D) Enkelvoudige exponentiële afvlakking met α = 0.85
#
# (7.3) Wat is de lijn B precies? Kies uit de mogelijkheden hieronder:
# (A) Eenvoudig voortschrijdend gemiddelde met periode 3
# (B) Eenvoudig voortschrijdend gemiddelde met periode 10
# (C) Enkelvoudige exponentiële afvlakking met α = 0.1
# (D) Enkelvoudige exponentiële afvlakking met α = 0.85
#
# (7.4) De forecast is berekend op basis waarvan? Kies uit de mogelijkheden hieronder:
# (A) Enkelvoudig exponentiële afvlakking
# (B) Dubbele expontiële afvlakking
# (C) Drievoudige exponentiële afvlakking

# %% [markdown]
# ## Antwoorden Vraag 7
#
# (7.1)  D
#
#
# (7.2) D
#
#
# (7.3) B
#
#
# (7.4) A

# %% [markdown]
# # Vraag 8 [5 pt]
#
# Een limonadefabrikant wil zijn limonadeblikjes een nieuw uiterlijk geven. Daartoe laat hij een testpanel van 180 potentiële klanten de aantrekkelijkheid van het oude en het nieuwe blikje beoordelen en ondervraagt hij hen over de bereidheid om het oude en het nieuwe blikje te kopen. De aantrekkelijkheid wordt beoordeeld op een schaal van 1 tot en met 7, met 1 de laagste en 7 de hoogste aantrekkelijkheid.
# We willen weten of de klanten het nieuwe blikje aantrekkelijker vinden dan het oude blikje. De data staat in limonadeblikjes.csv.
# (1) Welke toets moet je gebruiken om deze onderzoeksvraag te beantwoorden? Wees zo specifiek mogelijk!
# (2) Formuleer de nulhypothese en de alternatieve hypothese
# (3) Bereken de p-waarde
# (4) Trek een besluit op basis van de vorige stap en beantwoord de onderzoeksvraag.
# (5) In de cursus kwam Cohen's d aan bod om de effectgrootte te berekenen. Er bestaan echter veel alternatieven. Één van die alternatieven is Glass' Δ
# $$\Delta = \frac{\overline{x}_1 - \overline{x}_2}{s_1}$$
# met $\overline{x}_1$ en $\overline{x}_2$ het gemiddelde van elke groep en $s_1$ de standaard deviatie van de eerste sample.
# Bereken Glass' $\Delta$.

# %%
df = pd.read_csv("../dsai-ReeksA/limonadeblikjes.csv", sep=";")
df.head()
# Out:
#    test_klant  aantrekkelijkheid_oud  aantrekkelijkheid_nieuw
# 0           1                      5                        7
# 1           2                      7                        7
# 2           3                      6                        7
# 3           4                      1                        3
# 4           5                      3                        4

# %%
stats.ttest_rel(
    df["aantrekkelijkheid_oud"], df["aantrekkelijkheid_nieuw"], alternative="less"
)
# Out:
# TtestResult(statistic=-5.351419141432879, pvalue=1.3231562068750385e-07, df=179)

# %%
def cohen_d(a, b):
    na = len(a)
    nb = len(b)
    pooled_sd = np.sqrt(
        ((na - 1) * a.std(ddof=1) ** 2 + (nb - 1) * b.std(ddof=1) ** 2) / (na + nb - 2)
    )
    return (b.mean() - a.mean()) / pooled_sd

# %%
print(cohen_d(df["aantrekkelijkheid_oud"], df["aantrekkelijkheid_nieuw"]))
# Out:
# 0.2916637362306984

# %% [markdown]
# ## Antwoorden Vraag 8
#
# (8.1)   Je gebruikt de t-test voor paired samples
#
# (8.2)  The hypotheses are:
#
# - $H_0$: $\mu_1 - \mu_2 = 0$ (De aantrekkelijkheid van de blikjes is hetzelfde in beide groepen)
# - $H_1$: $\mu_1 - \mu_2 < 0$ (De aantrekkelijkheid is significant groter bij de nieuwe blikjes vergeleken met de oude blikjes)
#
# (8.3)  de p-waarde is =1.3231562068750385e-07
#
# (8.4)  De aantrekkelijkheid van de nieuwe blikjes is significant groter vergeleken met de aantrekkelijkheid van de oude blikjes. Zelfs bij een significantieniveau van 0.01 kan je de H0 rejecten of weigeren.
#
# (8.5)  Glass' $\Delta$ = 0.2916637362306984

# %% [markdown]
# ## Vraag 9 [6 pt]
#
# Gegeven het aantal gereden kilometers en de onderhoudskosten van vorig jaar van 23 vrachtwagens.
#
# (1) Maak de onderstaande plot  (Geef bij de Antwoorden het commando voor deze plot)
#
# ![image.png](data:image/png;base64,...)
#
# (2) Geef de vergelijking van de rechte
# (3) Bereken de correlatiecoëfficiënt (symbool + waarde)
# (4) Formuleer een interpretatie voor de waarde van de correlatiecoëfficiënt
# (5) Hoeveel zullen de onderhoudskosten ongeveer bedragen van een vrachtwagen die 5000 kilometer rijdt.
# (6) Hoeveel bedragen de vaste kosten van een vrachtwagen ongeveer, ook als die geen enkele kilometer heeft gereden?

# %%
sample_data = pd.DataFrame(
    data={
        "aantal_gereden_kilometers": [
            10500,
            9700,
            9200,
            8300,
            6500,
            4500,
            3500,
            2200,
            1800,
            9800,
            6600,
            3600,
            2500,
            3100,
            8400,
            9700,
            1800,
            10000,
            9800,
            9900,
            1100,
            2600,
            10300,
        ],
        "onderhoudskosten": [
            908.56,
            751.12,
            793.55,
            619.61,
            380.11,
            368.72,
            235.32,
            174.93,
            256.30,
            799.58,
            436.04,
            304.25,
            226.81,
            179.68,
            726.65,
            810.53,
            142.53,
            915.53,
            812.45,
            803.78,
            227.32,
            231.46,
            829.21,
        ],
    }
)

# %%
# 9.1
sns.regplot(
    x=sample_data["onderhoudskosten"], y=sample_data["aantal_gereden_kilometers"]
)
# Out:
# <Axes: xlabel='onderhoudskosten', ylabel='aantal_gereden_kilometers'>

# %%
cor = np.corrcoef(
    sample_data["onderhoudskosten"], sample_data["aantal_gereden_kilometers"]
)[0][1]
print(f"R = {cor}")
# Out:
# R = 0.9734957380089202

# %%
from sklearn.linear_model import LinearRegression

male_chinstrap_x = sample_data["aantal_gereden_kilometers"].values.reshape(-1, 1)
male_chinstrap_y = sample_data["onderhoudskosten"]

weight_model = LinearRegression().fit(male_chinstrap_x, male_chinstrap_y)

print(
    f"Regression line: ŷ = {weight_model.intercept_:.2f} + {weight_model.coef_[0]:.2f} x"
)
# Out:
# Regression line: ŷ = 13.77 + 0.08 x

# %%
weight_model.predict([[5000]])
# Out:
# array([413.26642121])

# %%
weight_model.predict([[0]])
# Out:
# array([13.77426462])

# %% [markdown]
# ## Antwoorden Vraag 9
#
# (9.1) boven
#
# (9.2)  Regression line: ŷ = 13.77 + 0.08 x
#
# (9.3) R = 0.9734957380089202
#
# (9.4) De sterkte van de lineaire relatie tussen de onderhoudskosten en het aantal gereden kilometers is exceptional.
#
# (9.5)413.26642121
#
# (9.6)13.7742646
